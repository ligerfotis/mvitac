# %%
import os

folderIn = 'calandradaraset/'
extension_in = 'h5'
namefiles = [each for each in os.listdir(folderIn) if each.endswith(extension_in)]
namefiles.sort()
print('Name files: %s' % namefiles)
print('Number files: %d' % len(namefiles))
# list of indexes of the files to load
idxs = [i for i in range(38)]
# create a list of filename that append the above indexes to 'calandra_corl2017_'
namefiles = ['calandra_corl2017_%03d.h5' % idx for idx in idxs]
print('Name files: %s' % namefiles)
# Out:
# Name files: ['calandra_corl2017_000.h5', 'calandra_corl2017_001.h5', 'calandra_corl2017_002.h5', 'calandra_corl2017_003.h5', 'calandra_corl2017_004.h5', 'calandra_corl2017_005.h5', 'calandra_corl2017_006.h5', 'calandra_corl2017_007.h5', 'calandra_corl2017_008.h5', 'calandra_corl2017_009.h5', 'calandra_corl2017_010.h5', 'calandra_corl2017_011.h5', 'calandra_corl2017_012.h5', 'calandra_corl2017_013.h5', 'calandra_corl2017_014.h5', 'calandra_corl2017_015.h5', 'calandra_corl2017_016.h5', 'calandra_corl2017_017.h5', 'calandra_corl2017_018.h5', 'calandra_corl2017_019.h5', 'calandra_corl2017_020.h5', 'calandra_corl2017_021.h5', 'calandra_corl2017_022.h5', 'calandra_corl2017_023.h5', 'calandra_corl2017_024.h5', 'calandra_corl2017_025.h5', 'calandra_corl2017_026.h5', 'calandra_corl2017_027.h5', 'calandra_corl2017_028.h5', 'calandra_corl2017_029.h5', 'calandra_corl2017_030.h5', 'calandra_corl2017_031.h5', 'calandra_corl2017_032.h5', 'calandra_corl2017_033.h5', 'calandra_corl2017_034.h5', 'calandra_corl2017_035.h5', 'calandra_corl2017_036.h5', 'calandra_corl2017_037.h5']
# Number files: 38
# Name files: ['calandra_corl2017_000.h5', 'calandra_corl2017_001.h5', 'calandra_corl2017_002.h5', 'calandra_corl2017_003.h5', 'calandra_corl2017_004.h5', 'calandra_corl2017_005.h5', 'calandra_corl2017_006.h5', 'calandra_corl2017_007.h5', 'calandra_corl2017_008.h5', 'calandra_corl2017_009.h5', 'calandra_corl2017_010.h5', 'calandra_corl2017_011.h5', 'calandra_corl2017_012.h5', 'calandra_corl2017_013.h5', 'calandra_corl2017_014.h5', 'calandra_corl2017_015.h5', 'calandra_corl2017_016.h5', 'calandra_corl2017_017.h5', 'calandra_corl2017_018.h5', 'calandra_corl2017_019.h5', 'calandra_corl2017_020.h5', 'calandra_corl2017_021.h5', 'calandra_corl2017_022.h5', 'calandra_corl2017_023.h5', 'calandra_corl2017_024.h5', 'calandra_corl2017_025.h5', 'calandra_corl2017_026.h5', 'calandra_corl2017_027.h5', 'calandra_corl2017_028.h5', 'calandra_corl2017_029.h5', 'calandra_corl2017_030.h5', 'calandra_corl2017_031.h5', 'calandra_corl2017_032.h5', 'calandra_corl2017_033.h5', 'calandra_corl2017_034.h5', 'calandra_corl2017_035.h5', 'calandra_corl2017_036.h5', 'calandra_corl2017_037.h5']

# %% [markdown]
# The script below takes the data from the h5 files and saves the images in the corresponding folders. The images are saved in the following format: object_name/sensor/<object_name>_<is_gripping>_<sensor>_<phase>_idx.png. The script takes several minutes to execute.

# %%
"""
This script takes several minutes to execute. 
Approximately 5 minutes per h5 file on a 5.8 GHz i9-13900K with 128gb ram, 
i.e. apprx 3hours for all 38 files.
"""
import os
import deepdish as dd
import matplotlib.pyplot as plt
import time

folderOut = 'calandra_objects/'
if not os.path.exists(folderOut):
    os.makedirs(folderOut)

start_time = time.time()

for namefile in namefiles:
    # Load data from file
    print('Loading file: %s' % namefile)
    t = dd.io.load(folderIn+namefile)
    n_data = len(t)
    print("N data: %d" % n_data)
    
    # iterate over the data, get the object name and the is_gripping flag per sample
    for i in range(n_data):
        object_name = t[i]['object_name']
        is_gripping = t[i]['is_gripping']
        # convert the object name to string
        object_name = object_name.decode('utf-8')
        
        # create the directory for the object if it does not exist
        if not os.path.exists(folderOut+object_name):
            os.makedirs(folderOut+object_name)
            
        # create the directory for the kinectA_rgb_before if it does not exist
        if not os.path.exists(folderOut+object_name+'/kinectA_rgb'):
            os.makedirs(folderOut+object_name+'/kinectA_rgb')
        if not os.path.exists(folderOut+object_name+'/gelsightA'):
            os.makedirs(folderOut+object_name+'/gelsightA')
        if not os.path.exists(folderOut+object_name+'/gelsightB'):
            os.makedirs(folderOut+object_name+'/gelsightB')
            
        # find the biggest index that a sample has on one of the directories above
        idx = 0
        while os.path.exists(folderOut+object_name+'/'+'kinectA_rgb/'+object_name+'_'+('success' if is_gripping else 'failure')+'_'+'kinectA_rgb_before'+'_'+str(idx)+'.png'):
            idx += 1
        
        # save the images in the corresponding directory
        plt.imsave(folderOut+object_name+'/'+'kinectA_rgb/'+object_name+'_'+('success' if is_gripping else 'failure')+'_'+'kinectA_rgb_before'+'_'+str(idx)+'.png', t[i]['kinectA_rgb_before'])
        plt.imsave(folderOut+object_name+'/'+'kinectA_rgb/'+object_name+'_'+('success' if is_gripping else 'failure')+'_'+'kinectA_rgb_during'+'_'+str(idx)+'.png', t[i]['kinectA_rgb_during'])
        plt.imsave(folderOut+object_name+'/'+'kinectA_rgb/'+object_name+'_'+('success' if is_gripping else 'failure')+'_'+'kinectA_rgb_after'+'_'+str(idx)+'.png', t[i]['kinectA_rgb_after'])
        plt.imsave(folderOut+object_name+'/'+'gelsightA/'+object_name+'_'+('success' if is_gripping else 'failure')+'_'+'gelsightA_before'+'_'+str(idx)+'.png', t[i]['gelsightA_before'])
        plt.imsave(folderOut+object_name+'/'+'gelsightA/'+object_name+'_'+('success' if is_gripping else 'failure')+'_'+'gelsightA_during'+'_'+str(idx)+'.png', t[i]['gelsightA_during'])
        plt.imsave(folderOut+object_name+'/'+'gelsightA/'+object_name+'_'+('success' if is_gripping else 'failure')+'_'+'gelsightA_after'+'_'+str(idx)+'.png', t[i]['gelsightA_after'])
        plt.imsave(folderOut+object_name+'/'+'gelsightB/'+object_name+'_'+('success' if is_gripping else 'failure')+'_'+'gelsightB_before'+'_'+str(idx)+'.png', t[i]['gelsightB_before'])
        plt.imsave(folderOut+object_name+'/'+'gelsightB/'+object_name+'_'+('success' if is_gripping else 'failure')+'_'+'gelsightB_during'+'_'+str(idx)+'.png', t[i]['gelsightB_during'])
        plt.imsave(folderOut+object_name+'/'+'gelsightB/'+object_name+'_'+('success' if is_gripping else 'failure')+'_'+'gelsightB_after'+'_'+str(idx)+'.png', t[i]['gelsightB_after'])
        
        # print progress alongside the time it took to execute
        if i % 50 == 0:
            print("Progress: %d/%d" % (i, n_data))
            print("Time elapsed: %d seconds" % (time.time() - start_time))
            
print("Done!")
print("Time elapsed: %d seconds" % (time.time() - start_time))
# Out:
# Loading file: calandra_corl2017_000.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 20 seconds
# Progress: 50/250
# Time elapsed: 90 seconds
# Progress: 100/250
# Time elapsed: 160 seconds
# Progress: 150/250
# Time elapsed: 230 seconds
# Progress: 200/250
# Time elapsed: 299 seconds
# Loading file: calandra_corl2017_001.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 388 seconds
# Progress: 50/250
# Time elapsed: 459 seconds
# Progress: 100/250
# Time elapsed: 529 seconds
# Progress: 150/250
# Time elapsed: 600 seconds
# Progress: 200/250
# Time elapsed: 671 seconds
# Loading file: calandra_corl2017_002.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 761 seconds
# Progress: 50/250
# Time elapsed: 831 seconds
# Progress: 100/250
# Time elapsed: 902 seconds
# Progress: 150/250
# Time elapsed: 971 seconds
# Progress: 200/250
# Time elapsed: 1042 seconds
# Loading file: calandra_corl2017_003.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 1133 seconds
# Progress: 50/250
# Time elapsed: 1202 seconds
# Progress: 100/250
# Time elapsed: 1271 seconds
# Progress: 150/250
# Time elapsed: 1341 seconds
# Progress: 200/250
# Time elapsed: 1410 seconds
# Loading file: calandra_corl2017_004.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 1499 seconds
# Progress: 50/250
# Time elapsed: 1569 seconds
# Progress: 100/250
# Time elapsed: 1638 seconds
# Progress: 150/250
# Time elapsed: 1707 seconds
# Progress: 200/250
# Time elapsed: 1777 seconds
# Loading file: calandra_corl2017_005.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 1866 seconds
# Progress: 50/250
# Time elapsed: 1936 seconds
# Progress: 100/250
# Time elapsed: 2005 seconds
# Progress: 150/250
# Time elapsed: 2074 seconds
# Progress: 200/250
# Time elapsed: 2144 seconds
# Loading file: calandra_corl2017_006.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 2233 seconds
# Progress: 50/250
# Time elapsed: 2300 seconds
# Progress: 100/250
# Time elapsed: 2368 seconds
# Progress: 150/250
# Time elapsed: 2436 seconds
# Progress: 200/250
# Time elapsed: 2503 seconds
# Loading file: calandra_corl2017_007.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 2591 seconds
# Progress: 50/250
# Time elapsed: 2659 seconds
# Progress: 100/250
# Time elapsed: 2727 seconds
# Progress: 150/250
# Time elapsed: 2794 seconds
# Progress: 200/250
# Time elapsed: 2861 seconds
# Loading file: calandra_corl2017_008.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 2950 seconds
# Progress: 50/250
# Time elapsed: 3018 seconds
# Progress: 100/250
# Time elapsed: 3086 seconds
# Progress: 150/250
# Time elapsed: 3155 seconds
# Progress: 200/250
# Time elapsed: 3223 seconds
# Loading file: calandra_corl2017_009.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 3312 seconds
# Progress: 50/250
# Time elapsed: 3381 seconds
# Progress: 100/250
# Time elapsed: 3450 seconds
# Progress: 150/250
# Time elapsed: 3520 seconds
# Progress: 200/250
# Time elapsed: 3590 seconds
# Loading file: calandra_corl2017_010.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 3679 seconds
# Progress: 50/250
# Time elapsed: 3749 seconds
# Progress: 100/250
# Time elapsed: 3819 seconds
# Progress: 150/250
# Time elapsed: 3889 seconds
# Progress: 200/250
# Time elapsed: 3960 seconds
# Loading file: calandra_corl2017_011.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 4050 seconds
# Progress: 50/250
# Time elapsed: 4119 seconds
# Progress: 100/250
# Time elapsed: 4189 seconds
# Progress: 150/250
# Time elapsed: 4259 seconds
# Progress: 200/250
# Time elapsed: 4329 seconds
# Loading file: calandra_corl2017_012.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 4419 seconds
# Progress: 50/250
# Time elapsed: 4488 seconds
# Progress: 100/250
# Time elapsed: 4558 seconds
# Progress: 150/250
# Time elapsed: 4628 seconds
# Progress: 200/250
# Time elapsed: 4698 seconds
# Loading file: calandra_corl2017_013.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 4789 seconds
# Progress: 50/250
# Time elapsed: 4860 seconds
# Progress: 100/250
# Time elapsed: 4930 seconds
# Progress: 150/250
# Time elapsed: 5001 seconds
# Progress: 200/250
# Time elapsed: 5071 seconds
# Loading file: calandra_corl2017_014.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 5162 seconds
# Progress: 50/250
# Time elapsed: 5232 seconds
# Progress: 100/250
# Time elapsed: 5303 seconds
# Progress: 150/250
# Time elapsed: 5373 seconds
# Progress: 200/250
# Time elapsed: 5443 seconds
# Loading file: calandra_corl2017_015.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 5534 seconds
# Progress: 50/250
# Time elapsed: 5604 seconds
# Progress: 100/250
# Time elapsed: 5675 seconds
# Progress: 150/250
# Time elapsed: 5746 seconds
# Progress: 200/250
# Time elapsed: 5817 seconds
# Loading file: calandra_corl2017_016.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 5908 seconds
# Progress: 50/250
# Time elapsed: 5978 seconds
# Progress: 100/250
# Time elapsed: 6049 seconds
# Progress: 150/250
# Time elapsed: 6123 seconds
# Progress: 200/250
# Time elapsed: 6197 seconds
# Loading file: calandra_corl2017_017.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 6291 seconds
# Progress: 50/250
# Time elapsed: 6364 seconds
# Progress: 100/250
# Time elapsed: 6437 seconds
# Progress: 150/250
# Time elapsed: 6511 seconds
# Progress: 200/250
# Time elapsed: 6584 seconds
# Loading file: calandra_corl2017_018.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 6678 seconds
# Progress: 50/250
# Time elapsed: 6750 seconds
# Progress: 100/250
# Time elapsed: 6824 seconds
# Progress: 150/250
# Time elapsed: 6900 seconds
# Progress: 200/250
# Time elapsed: 6976 seconds
# Loading file: calandra_corl2017_019.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 7073 seconds
# Progress: 50/250
# Time elapsed: 7149 seconds
# Progress: 100/250
# Time elapsed: 7225 seconds
# Progress: 150/250
# Time elapsed: 7302 seconds
# Progress: 200/250
# Time elapsed: 7379 seconds
# Loading file: calandra_corl2017_020.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 7477 seconds
# Progress: 50/250
# Time elapsed: 7554 seconds
# Progress: 100/250
# Time elapsed: 7630 seconds
# Progress: 150/250
# Time elapsed: 7707 seconds
# Progress: 200/250
# Time elapsed: 7786 seconds
# Loading file: calandra_corl2017_021.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 7887 seconds
# Progress: 50/250
# Time elapsed: 7967 seconds
# Progress: 100/250
# Time elapsed: 8047 seconds
# Progress: 150/250
# Time elapsed: 8127 seconds
# Progress: 200/250
# Time elapsed: 8206 seconds
# Loading file: calandra_corl2017_022.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 8306 seconds
# Progress: 50/250
# Time elapsed: 8384 seconds
# Progress: 100/250
# Time elapsed: 8463 seconds
# Progress: 150/250
# Time elapsed: 8539 seconds
# Progress: 200/250
# Time elapsed: 8616 seconds
# Loading file: calandra_corl2017_023.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 8715 seconds
# Progress: 50/250
# Time elapsed: 8792 seconds
# Progress: 100/250
# Time elapsed: 8871 seconds
# Progress: 150/250
# Time elapsed: 8952 seconds
# Progress: 200/250
# Time elapsed: 9033 seconds
# Loading file: calandra_corl2017_024.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 9136 seconds
# Progress: 50/250
# Time elapsed: 9216 seconds
# Progress: 100/250
# Time elapsed: 9297 seconds
# Progress: 150/250
# Time elapsed: 9378 seconds
# Progress: 200/250
# Time elapsed: 9458 seconds
# Loading file: calandra_corl2017_025.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 9562 seconds
# Progress: 50/250
# Time elapsed: 9641 seconds
# Progress: 100/250
# Time elapsed: 9721 seconds
# Progress: 150/250
# Time elapsed: 9801 seconds
# Progress: 200/250
# Time elapsed: 9880 seconds
# Loading file: calandra_corl2017_026.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 9982 seconds
# Progress: 50/250
# Time elapsed: 10062 seconds
# Progress: 100/250
# Time elapsed: 10142 seconds
# Progress: 150/250
# Time elapsed: 10221 seconds
# Progress: 200/250
# Time elapsed: 10299 seconds
# Loading file: calandra_corl2017_027.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 10400 seconds
# Progress: 50/250
# Time elapsed: 10479 seconds
# Progress: 100/250
# Time elapsed: 10557 seconds
# Progress: 150/250
# Time elapsed: 10635 seconds
# Progress: 200/250
# Time elapsed: 10714 seconds
# Loading file: calandra_corl2017_028.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 10815 seconds
# Progress: 50/250
# Time elapsed: 10893 seconds
# Progress: 100/250
# Time elapsed: 10972 seconds
# Progress: 150/250
# Time elapsed: 11051 seconds
# Progress: 200/250
# Time elapsed: 11130 seconds
# Loading file: calandra_corl2017_029.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 11232 seconds
# Progress: 50/250
# Time elapsed: 11311 seconds
# Progress: 100/250
# Time elapsed: 11390 seconds
# Progress: 150/250
# Time elapsed: 11469 seconds
# Progress: 200/250
# Time elapsed: 11547 seconds
# Loading file: calandra_corl2017_030.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 11647 seconds
# Progress: 50/250
# Time elapsed: 11725 seconds
# Progress: 100/250
# Time elapsed: 11802 seconds
# Progress: 150/250
# Time elapsed: 11879 seconds
# Progress: 200/250
# Time elapsed: 11956 seconds
# Loading file: calandra_corl2017_031.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 12055 seconds
# Progress: 50/250
# Time elapsed: 12132 seconds
# Progress: 100/250
# Time elapsed: 12209 seconds
# Progress: 150/250
# Time elapsed: 12286 seconds
# Progress: 200/250
# Time elapsed: 12364 seconds
# Loading file: calandra_corl2017_032.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 12463 seconds
# Progress: 50/250
# Time elapsed: 12540 seconds
# Progress: 100/250
# Time elapsed: 12617 seconds
# Progress: 150/250
# Time elapsed: 12695 seconds
# Progress: 200/250
# Time elapsed: 12773 seconds
# Loading file: calandra_corl2017_033.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 12871 seconds
# Progress: 50/250
# Time elapsed: 12948 seconds
# Progress: 100/250
# Time elapsed: 13025 seconds
# Progress: 150/250
# Time elapsed: 13102 seconds
# Progress: 200/250
# Time elapsed: 13179 seconds
# Loading file: calandra_corl2017_034.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 13278 seconds
# Progress: 50/250
# Time elapsed: 13357 seconds
# Progress: 100/250
# Time elapsed: 13436 seconds
# Progress: 150/250
# Time elapsed: 13515 seconds
# Progress: 200/250
# Time elapsed: 13594 seconds
# Loading file: calandra_corl2017_035.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 13694 seconds
# Progress: 50/250
# Time elapsed: 13771 seconds
# Progress: 100/250
# Time elapsed: 13840 seconds
# Progress: 150/250
# Time elapsed: 13912 seconds
# Progress: 200/250
# Time elapsed: 13982 seconds
# Loading file: calandra_corl2017_036.h5
# N data: 250
# Progress: 0/250
# Time elapsed: 14075 seconds
# Progress: 50/250
# Time elapsed: 14145 seconds
# Progress: 100/250
# Time elapsed: 14214 seconds
# Progress: 150/250
# Time elapsed: 14288 seconds
# Progress: 200/250
# Time elapsed: 14360 seconds
# Loading file: calandra_corl2017_037.h5
# N data: 46
# Progress: 0/46
# Time elapsed: 14435 seconds
# Done!
# Time elapsed: 14498 seconds

# %% [markdown]
# Remove objects that have only success or failure samples

# %%
# check if an object has only success or failure samples and delete this object folder
import os
import shutil

folderOut = 'calandra_objects/'
objects = [each for each in os.listdir(folderOut) if os.path.isdir(folderOut+each)]
for obj in objects:
    success = [each for each in os.listdir(folderOut+obj) if each.endswith('success')]
    failure = [each for each in os.listdir(folderOut+obj) if each.endswith('failure')]
    if len(success) == 0 or len(failure) == 0:
        shutil.rmtree(folderOut+obj)
        print("Removed object: %s" % obj)

# %% [markdown]
# Use the train and test object lists to split the data into train and test sets object_wise

# %%
import os
import shutil

folderOut = 'calandra_objects_split_object_wise/'
train_objects = ['cinnamon', 'potato', 'aspirin', 'red_turtle', 'happy_fall_stone', 'monster_truck', 'soft_red_cube', 'lime', 'ogx_shampoo', 'peanut_butter', 'chocolate_shake', 'webcam_box', 'rubics_cube', 'muffin', 'red_bull', 'purple_small_plastic_fruit', 'onion', 'soft_blue_hexagon', 'plastic_cow', 'fox_head', 'small_coffe_cup', 'lemon', 'red_apple', '3d_printed_white_ball', 'set_small_plastic_men_police_man', 'dog_toy_ice_cream_cone', 'playdoh_container', 'bandaid_box', 'emergency_stop_button_for_sawyer', 'plastic_duck', 'brown_paper_cup_2_upside', 'mentos_gum_can']
test_objects = ['international_travel_adapter', '3d_printed_blue_connector', 'soft_zebra', 'fake_flower_in_pot', 'metal_can', 'french_dip', 'metal_cylinder_with_holes', 'soft_beer_bottle_holder']

if not os.path.exists(folderOut):
    os.makedirs(folderOut)
if not os.path.exists(folderOut+'train'):
    os.makedirs(folderOut+'train')
if not os.path.exists(folderOut+'test'):
    os.makedirs(folderOut+'test')
if not os.path.exists(folderOut+'train'+'/kinectA_rgb'):
    os.makedirs(folderOut+'train'+'/kinectA_rgb')
if not os.path.exists(folderOut+'train'+'/gelsightA'):
    os.makedirs(folderOut+'train'+'/gelsightA')
if not os.path.exists(folderOut+'train'+'/gelsightB'):
    os.makedirs(folderOut+'train'+'/gelsightB')
if not os.path.exists(folderOut+'test'+'/kinectA_rgb'):
    os.makedirs(folderOut+'test'+'/kinectA_rgb')
if not os.path.exists(folderOut+'test'+'/gelsightA'):
    os.makedirs(folderOut+'test'+'/gelsightA')
if not os.path.exists(folderOut+'test'+'/gelsightB'):
    os.makedirs(folderOut+'test'+'/gelsightB')
    
# copy the train objects sample in the train/kinectA_rgb, train/gelsightA and train/gelsightB folders
for obj in train_objects:
    for sensor in ['kinectA_rgb', 'gelsightA', 'gelsightB']:
        # copy all samples of the object
        for each in os.listdir(folderOut+obj+'/'+sensor):
            shutil.copy(folderOut+obj+'/'+sensor+'/'+each, folderOut+'train/'+sensor+'/'+each)
            
# copy the test objects sample in the test/kinectA_rgb, test/gelsightA and test/gelsightB folders
for obj in test_objects:
    for sensor in ['kinectA_rgb', 'gelsightA', 'gelsightB']:
        # copy all samples of the object
        for each in os.listdir(folderOut+obj+'/'+sensor):
            shutil.copy(folderOut+obj+'/'+sensor+'/'+each, folderOut+'test/'+sensor+'/'+each)
